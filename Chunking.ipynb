# %% [markdown]
# * group of words is called tokens
# * collection of tokens is called chunks

# %% [markdown]
# ###CHUNKING

# %%
from transformers import AutoTokenizer

# %%
document="Artificial Intelligence (AI) is a branch of computer science that focuses on creating machines and systems capable of performing tasks that normally require human intelligence. These tasks include learning, reasoning, problem-solving, understanding language, recognizing images, and making decisions. Machine Learning (ML) is a subset of AI that allows computers to learn from data and improve their performance without being explicitly programmed for every task. Instead of following fixed instructions, ML algorithms analyze large amounts of data, identify patterns, and make predictions or decisions based on that data. AI is the broader concept of building smart machines, while ML is one of the main techniques used to achieve that intelligence.AI and ML are widely used in our daily lives, often without us realizing it. For example, voice assistants like Siri and Alexa use AI to understand and respond to human speech. Recommendation systems on platforms like YouTube and Netflix use ML algorithms to suggest videos and movies based on user preferences and past behavior. In healthcare, AI helps doctors diagnose diseases more accurately and at earlier stages by analyzing medical images and patient data. In banking and finance, ML models are used for fraud detection, credit scoring, and risk management. E-commerce companies use AI to personalize shopping experiences and predict customer needs.There are different types of machine learning, such as supervised learning, unsupervised learning, and reinforcement learning. In supervised learning, models are trained on labeled data, meaning the correct output is already known. In unsupervised learning, models find hidden patterns in data without labeled outputs. Reinforcement learning involves training systems to make decisions by rewarding correct actions. AI and ML help automate repetitive tasks, improve efficiency, and support data-driven decision-making. However, challenges such as data privacy, security, and ethical concerns must be addressed carefully. Overall, AI and ML are transforming industries and shaping the future of technology in powerful and innovative ways."
model_name = "sentence-transformers/all-MiniLM-L6-v2"
tokenizer=AutoTokenizer.from_pretrained(model_name)
tokens=tokenizer.encode(document)
print(tokens)
# Out:
# [101, 7976, 4454, 1006, 9932, 1007, 2003, 1037, 3589, 1997, 3274, 2671, 2008, 7679, 2006, 4526, 6681, 1998, 3001, 5214, 1997, 4488, 8518, 2008, 5373, 5478, 2529, 4454, 1012, 2122, 8518, 2421, 4083, 1010, 13384, 1010, 3291, 1011, 13729, 1010, 4824, 2653, 1010, 14622, 4871, 1010, 1998, 2437, 6567, 1012, 3698, 4083, 1006, 19875, 1007, 2003, 1037, 16745, 1997, 9932, 2008, 4473, 7588, 2000, 4553, 2013, 2951, 1998, 5335, 2037, 2836, 2302, 2108, 12045, 16984, 2005, 2296, 4708, 1012, 2612, 1997, 2206, 4964, 8128, 1010, 19875, 13792, 17908, 2312, 8310, 1997, 2951, 1010, 6709, 7060, 1010, 1998, 2191, 20932, 2030, 6567, 2241, 2006, 2008, 2951, 1012, 9932, 2003, 1996, 12368, 4145, 1997, 2311, 6047, 6681, 1010, 2096, 19875, 2003, 2028, 1997, 1996, 2364, 5461, 2109, 2000, 6162, 2008, 4454, 1012, 9932, 1998, 19875, 2024, 4235, 2109, 1999, 2256, 3679, 3268, 1010, 2411, 2302, 2149, 9301, 2009, 1012, 2005, 2742, 1010, 2376, 16838, 2066, 2909, 2072, 1998, 24969, 2224, 9932, 2000, 3305, 1998, 6869, 2000, 2529, 4613, 1012, 12832, 3001, 2006, 7248, 2066, 7858, 1998, 20907, 2224, 19875, 13792, 2000, 6592, 6876, 1998, 5691, 2241, 2006, 5310, 18394, 1998, 2627, 5248, 1012, 1999, 9871, 1010, 9932, 7126, 7435, 22939, 26745, 3366, 7870, 2062, 14125, 1998, 2012, 3041, 5711, 2011, 20253, 2966, 4871, 1998, 5776, 2951, 1012, 1999, 8169, 1998, 5446, 1010, 19875, 4275, 2024, 2109, 2005, 9861, 10788, 1010, 4923, 4577, 1010, 1998, 3891, 2968, 1012, 1041, 1011, 6236, 3316, 2224, 9932, 2000, 3167, 4697, 6023, 6322, 1998, 16014, 8013, 3791, 1012, 2045, 2024, 2367, 4127, 1997, 3698, 4083, 1010, 2107, 2004, 13588, 4083, 1010, 4895, 6342, 4842, 11365, 2098, 4083, 1010, 1998, 23895, 4083, 1012, 1999, 13588, 4083, 1010, 4275, 2024, 4738, 2006, 12599, 2951, 1010, 3574, 1996, 6149, 6434, 2003, 2525, 2124, 1012, 1999, 4895, 6342, 4842, 11365, 2098, 4083, 1010, 4275, 2424, 5023, 7060, 1999, 2951, 2302, 12599, 27852, 1012, 23895, 4083, 7336, 2731, 3001, 2000, 2191, 6567, 2011, 10377, 2075, 6149, 4506, 1012, 9932, 1998, 19875, 2393, 8285, 8585, 23563, 8518, 1010, 5335, 8122, 1010, 1998, 2490, 2951, 1011, 5533, 3247, 1011, 2437, 1012, 2174, 1010, 7860, 2107, 2004, 2951, 9394, 1010, 3036, 1010, 1998, 12962, 5936, 2442, 2022, 8280, 5362, 1012, 3452, 1010, 9932, 1998, 19875, 2024, 17903, 6088, 1998, 20300, 1996, 2925, 1997, 2974, 1999, 3928, 1998, 9525, 3971, 1012, 102]

# %%
tokenizer.decode(tokens)
# Out:
# '[CLS] artificial intelligence ( ai ) is a branch of computer science that focuses on creating machines and systems capable of performing tasks that normally require human intelligence. these tasks include learning, reasoning, problem - solving, understanding language, recognizing images, and making decisions. machine learning ( ml ) is a subset of ai that allows computers to learn from data and improve their performance without being explicitly programmed for every task. instead of following fixed instructions, ml algorithms analyze large amounts of data, identify patterns, and make predictions or decisions based on that data. ai is the broader concept of building smart machines, while ml is one of the main techniques used to achieve that intelligence. ai and ml are widely used in our daily lives, often without us realizing it. for example, voice assistants like siri and alexa use ai to understand and respond to human speech. recommendation systems on platforms like youtube and netflix use ml algorithms to suggest videos and movies based on user preferences and past behavior. in healthcare, ai helps doctors diagnose diseases more accurately and at earlier stages by analyzing medical images and patient data. in banking and finance, ml models are used for fraud detection, credit scoring, and risk management. e - commerce companies use ai to personalize shopping experiences and predict customer needs. there are different types of machine learning, such as supervised learning, unsupervised learning, and reinforcement learning. in supervised learning, models are trained on labeled data, meaning the correct output is already known. in unsupervised learning, models find hidden patterns in data without labeled outputs. reinforcement learning involves training systems to make decisions by rewarding correct actions. ai and ml help automate repetitive tasks, improve efficiency, and support data - driven decision - making. however, challenges such as data privacy, security, and ethical concerns must be addressed carefully. overall, ai and ml are transforming industries and shaping the future of technology in powerful and innovative ways. [SEP]'

# %%
len(tokens)
# Out:
# 386

# %%
# words = document.split()
# chunk_size=50
# chunk_overlapping = 10
# step = chunk_size - chunk_overlapping
# print(step)
# texts=[]
# main_list = []
# chunk_id = 0
# for i in range(0, len(document),step):
#     print(i)
#     chunk = words[i:i + chunk_size]
#     texts.append(chunk)

#     if not chunk:
#         break

#     chunk_dict = {
#         "chunks_str": " ".join(chunk),
#         "chunks_id":chunk_id,
#         "chunk_numbers":tokens
#     }

#     main_list.append(chunk_dict)
#     chunk_id += 1
#     if i + chunk_size >= len(words):
#       break
# print(texts)
# print(main_list)
# print(len(main_list))
# Out:
# 40
# 0
# 40
# 80
# 120
# 160
# 200
# 240
# 280
# [['Artificial', 'Intelligence', '(AI)', 'is', 'a', 'branch', 'of', 'computer', 'science', 'that', 'focuses', 'on', 'creating', 'machines', 'and', 'systems', 'capable', 'of', 'performing', 'tasks', 'that', 'normally', 'require', 'human', 'intelligence.', 'These', 'tasks', 'include', 'learning,', 'reasoning,', 'problem-solving,', 'understanding', 'language,', 'recognizing', 'images,', 'and', 'making', 'decisions.', 'Machine', 'Learning', '(ML)', 'is', 'a', 'subset', 'of', 'AI', 'that', 'allows', 'computers', 'to'], ['(ML)', 'is', 'a', 'subset', 'of', 'AI', 'that', 'allows', 'computers', 'to', 'learn', 'from', 'data', 'and', 'improve', 'their', 'performance', 'without', 'being', 'explicitly', 'programmed', 'for', 'every', 'task.', 'Instead', 'of', 'following', 'fixed', 'instructions,', 'ML', 'algorithms', 'analyze', 'large', 'amounts', 'of', 'data,', 'identify', 'patterns,', 'and', 'make', 'predictions', 'or', 'decisions', 'based', 'on', 'that', 'data.', 'AI', 'is', 'the'], ['predictions', 'or', 'decisions', 'based', 'on', 'that', 'data.', 'AI', 'is', 'the', 'broader', 'concept', 'of', 'building', 'smart', 'machines,', 'while', 'ML', 'is', 'one', 'of', 'the', 'main', 'techniques', 'used', 'to', 'achieve', 'that', 'intelligence.AI', 'and', 'ML', 'are', 'widely', 'used', 'in', 'our', 'daily', 'lives,', 'often', 'without', 'us', 'realizing', 'it.', 'For', 'example,', 'voice', 'assistants', 'like', 'Siri', 'and'], ['us', 'realizing', 'it.', 'For', 'example,', 'voice', 'assistants', 'like', 'Siri', 'and', 'Alexa', 'use', 'AI', 'to', 'understand', 'and', 'respond', 'to', 'human', 'speech.', 'Recommendation', 'systems', 'on', 'platforms', 'like', 'YouTube', 'and', 'Netflix', 'use', 'ML', 'algorithms', 'to', 'suggest', 'videos', 'and', 'movies', 'based', 'on', 'user', 'preferences', 'and', 'past', 'behavior.', 'In', 'healthcare,', 'AI', 'helps', 'doctors', 'diagnose', 'diseases'], ['and', 'past', 'behavior.', 'In', 'healthcare,', 'AI', 'helps', 'doctors', 'diagnose', 'diseases', 'more', 'accurately', 'and', 'at', 'earlier', 'stages', 'by', 'analyzing', 'medical', 'images', 'and', 'patient', 'data.', 'In', 'banking', 'and', 'finance,', 'ML', 'models', 'are', 'used', 'for', 'fraud', 'detection,', 'credit', 'scoring,', 'and', 'risk', 'management.', 'E-commerce', 'companies', 'use', 'AI', 'to', 'personalize', 'shopping', 'experiences', 'and', 'predict', 'customer'], ['companies', 'use', 'AI', 'to', 'personalize', 'shopping', 'experiences', 'and', 'predict', 'customer', 'needs.There', 'are', 'different', 'types', 'of', 'machine', 'learning,', 'such', 'as', 'supervised', 'learning,', 'unsupervised', 'learning,', 'and', 'reinforcement', 'learning.', 'In', 'supervised', 'learning,', 'models', 'are', 'trained', 'on', 'labeled', 'data,', 'meaning', 'the', 'correct', 'output', 'is', 'already', 'known.', 'In', 'unsupervised', 'learning,', 'models', 'find', 'hidden', 'patterns', 'in'], ['already', 'known.', 'In', 'unsupervised', 'learning,', 'models', 'find', 'hidden', 'patterns', 'in', 'data', 'without', 'labeled', 'outputs.', 'Reinforcement', 'learning', 'involves', 'training', 'systems', 'to', 'make', 'decisions', 'by', 'rewarding', 'correct', 'actions.', 'AI', 'and', 'ML', 'help', 'automate', 'repetitive', 'tasks,', 'improve', 'efficiency,', 'and', 'support', 'data-driven', 'decision-making.', 'However,', 'challenges', 'such', 'as', 'data', 'privacy,', 'security,', 'and', 'ethical', 'concerns', 'must'], ['challenges', 'such', 'as', 'data', 'privacy,', 'security,', 'and', 'ethical', 'concerns', 'must', 'be', 'addressed', 'carefully.', 'Overall,', 'AI', 'and', 'ML', 'are', 'transforming', 'industries', 'and', 'shaping', 'the', 'future', 'of', 'technology', 'in', 'powerful', 'and', 'innovative', 'ways.']]
# [{'chunks_str': 'Artificial Intelligence (AI) is a branch of computer science that focuses on creating machines and systems capable of performing tasks that normally require human intelligence. These tasks include learning, reasoning, problem-solving, understanding language, recognizing images, and making decisions. Machine Learning (ML) is a subset of AI that allows computers to', 'chunks_id': 0, 'chunk_numbers': [101, 7976, 4454, 1006, 9932, 1007, 2003, 1037, 3589, 1997, 3274, 2671, 2008, 7679, 2006, 4526, 6681, 1998, 3001, 5214, 1997, 4488, 8518, 2008, 5373, 5478, 2529, 4454, 1012, 2122, 8518, 2421, 4083, 1010, 13384, 1010, 3291, 1011, 13729, 1010, 4824, 2653, 1010, 14622, 4871, 1010, 1998, 2437, 6567, 1012, 3698, 4083, 1006, 19875, 1007, 2003, 1037, 16745, 1997, 9932, 2008, 4473, 7588, 2000, 4553, 2013, 2951, 1998, 5335, 2037, 2836, 2302, 2108, 12045, 16984, 2005, 2296, 4708, 1012, 2612, 1997, 2206, 4964, 8128, 1010, 19875, 13792, 17908, 2312, 8310, 1997, 2951, 1010, 6709, 7060, 1010, 1998, 2191, 20932, 2030, 6567, 2241, 2006, 2008, 2951, 1012, 9932, 2003, 1996, 12368, 4145, 1997, 2311, 6047, 6681, 1010, 2096, 19875, 2003, 2028, 1997, 1996, 2364, 5461, 2109, 2000, 6162, 2008, 4454, 1012, 9932, 1998, 19875, 2024, 4235, 2109, 1999, 2256, 3679, 3268, 1010, 2411, 2302, 2149, 9301, 2009, 1012, 2005, 2742, 1010, 2376, 16838, 2066, 2909, 2072, 1998, 24969, 2224, 9932, 2000, 3305, 1998, 6869, 2000, 2529, 4613, 1012, 12832, 3001, 2006, 7248, 2066, 7858, 1998, 20907, 2224, 19875, 13792, 2000, 6592, 6876, 1998, 5691, 2241, 2006, 5310, 18394, 1998, 2627, 5248, 1012, 1999, 9871, 1010, 9932, 7126, 7435, 22939, 26745, 3366, 7870, 2062, 14125, 1998, 2012, 3041, 5711, 2011, 20253, 2966, 4871, 1998, 5776, 2951, 1012, 1999, 8169, 1998, 5446, 1010, 19875, 4275, 2024, 2109, 2005, 9861, 10788, 1010, 4923, 4577, 1010, 1998, 3891, 2968, 1012, 1041, 1011, 6236, 3316, 2224, 9932, 2000, 3167, 4697, 6023, 6322, 1998, 16014, 8013, 3791, 1012, 2045, 2024, 2367, 4127, 1997, 3698, 4083, 1010, 2107, 2004, 13588, 4083, 1010, 4895, 6342, 4842, 11365, 2098, 4083, 1010, 1998, 23895, 4083, 1012, 1999, 13588, 4083, 1010, 4275, 2024, 4738, 2006, 12599, 2951, 1010, 3574, 1996, 6149, 6434, 2003, 2525, 2124, 1012, 1999, 4895, 6342, 4842, 11365, 2098, 4083, 1010, 4275, 2424, 5023, 7060, 1999, 2951, 2302, 12599, 27852, 1012, 23895, 4083, 7336, 2731, 3001, 2000, 2191, 6567, 2011, 10377, 2075, 6149, 4506, 1012, 9932, 1998, 19875, 2393, 8285, 8585, 23563, 8518, 1010, 5335, 8122, 1010, 1998, 2490, 2951, 1011, 5533, 3247, 1011, 2437, 1012, 2174, 1010, 7860, 2107, 2004, 2951, 9394, 1010, 3036, 1010, 1998, 12962, 5936, 2442, 2022, 8280, 5362, 1012, 3452, 1010, 9932, 1998, 19875, 2024, 17903, 6088, 1998, 20300, 1996, 2925, 1997, 2974, 1999, 3928, 1998, 9525, 3971, 1012, 102]}, {'chunks_str': '(ML) is a subset of AI that allows computers to learn from data and improve their performance without being explicitly programmed for every task. Instead of following fixed instructions, ML algorithms analyze large amounts of data, identify patterns, and make predictions or decisions based on that data. AI is the', 'chunks_id': 1, 'chunk_numbers': [101, 7976, 4454, 1006, 9932, 1007, 2003, 1037, 3589, 1997, 3274, 2671, 2008, 7679, 2006, 4526, 6681, 1998, 3001, 5214, 1997, 4488, 8518, 2008, 5373, 5478, 2529, 4454, 1012, 2122, 8518, 2421, 4083, 1010, 13384, 1010, 3291, 1011, 13729, 1010, 4824, 2653, 1010, 14622, 4871, 1010, 1998, 2437, 6567, 1012, 3698, 4083, 1006, 19875, 1007, 2003, 1037, 16745, 1997, 9932, 2008, 4473, 7588, 2000, 4553, 2013, 2951, 1998, 5335, 2037, 2836, 2302, 2108, 12045, 16984, 2005, 2296, 4708, 1012, 2612, 1997, 2206, 4964, 8128, 1010, 19875, 13792, 17908, 2312, 8310, 1997, 2951, 1010, 6709, 7060, 1010, 1998, 2191, 20932, 2030, 6567, 2241, 2006, 2008, 2951, 1012, 9932, 2003, 1996, 12368, 4145, 1997, 2311, 6047, 6681, 1010, 2096, 19875, 2003, 2028, 1997, 1996, 2364, 5461, 2109, 2000, 6162, 2008, 4454, 1012, 9932, 1998, 19875, 2024, 4235, 2109, 1999, 2256, 3679, 3268, 1 ...
# 8

# %%
chunks=[]  ##or
chunk_size=50
chunk_overlapping = 10
step = chunk_size - chunk_overlapping
for i in range(0,len(tokens),step):
  chunk=tokens[i:i+chunk_size]
  chunks.append(tokenizer.decode(chunk))
print(chunks,len(chunks))
# Out:
# ['[CLS] artificial intelligence ( ai ) is a branch of computer science that focuses on creating machines and systems capable of performing tasks that normally require human intelligence. these tasks include learning, reasoning, problem - solving, understanding language, recognizing images, and making decisions.', 'understanding language, recognizing images, and making decisions. machine learning ( ml ) is a subset of ai that allows computers to learn from data and improve their performance without being explicitly programmed for every task. instead of following fixed instructions, ml algorithms analyze large amounts', 'of following fixed instructions, ml algorithms analyze large amounts of data, identify patterns, and make predictions or decisions based on that data. ai is the broader concept of building smart machines, while ml is one of the main techniques used to achieve that intelligence.', 'of the main techniques used to achieve that intelligence. ai and ml are widely used in our daily lives, often without us realizing it. for example, voice assistants like siri and alexa use ai to understand and respond to human speech. recommendation systems on', 'understand and respond to human speech. recommendation systems on platforms like youtube and netflix use ml algorithms to suggest videos and movies based on user preferences and past behavior. in healthcare, ai helps doctors diagnose diseases more accurately and at earlier stages by analyzing medical', 'diseases more accurately and at earlier stages by analyzing medical images and patient data. in banking and finance, ml models are used for fraud detection, credit scoring, and risk management. e - commerce companies use ai to personalize shopping experiences and predict customer needs', 'ai to personalize shopping experiences and predict customer needs. there are different types of machine learning, such as supervised learning, unsupervised learning, and reinforcement learning. in supervised learning, models are trained on labeled data, meaning the correct output', 'are trained on labeled data, meaning the correct output is already known. in unsupervised learning, models find hidden patterns in data without labeled outputs. reinforcement learning involves training systems to make decisions by rewarding correct actions. ai and ml help', 'by rewarding correct actions. ai and ml help automate repetitive tasks, improve efficiency, and support data - driven decision - making. however, challenges such as data privacy, security, and ethical concerns must be addressed carefully. overall, ai and ml', 'must be addressed carefully. overall, ai and ml are transforming industries and shaping the future of technology in powerful and innovative ways. [SEP]'] 10

# %% [markdown]
# ###RAG

# %%
pip install faiss-cpu
# Out:
# Requirement already satisfied: faiss-cpu in /usr/local/lib/python3.12/dist-packages (1.13.2)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /usr/local/lib/python3.12/dist-packages (from faiss-cpu) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from faiss-cpu) (26.0)

# %%
import numpy as np
import faiss
import spacy
from sentence_transformers import SentenceTransformer
from transformers import pipeline

# %%
embedding_model = SentenceTransformer(model_name)
embedding_model

# %%
embedding=embedding_model.encode(chunks)
embedding
# Out:
# array([[-0.0368399 , -0.04160651, -0.01825606, ...,  0.09273165,
#          0.06128611, -0.06420613],
#        [ 0.01414315, -0.02458274,  0.03609606, ...,  0.07260187,
#          0.0239953 , -0.09707217],
#        [ 0.00780186, -0.04545987,  0.03571987, ...,  0.08959997,
#          0.05761595, -0.08213539],
#        ...,
#        [-0.05977244, -0.0291439 , -0.0361167 , ...,  0.04198584,
#          0.03008492, -0.02737905],
#        [-0.05008633, -0.0333593 ,  0.00885151, ...,  0.00210371,
#         -0.02952717, -0.1022985 ],
#        [ 0.0162498 , -0.02872442,  0.03382298, ..., -0.04925361,
#          0.05692871, -0.02271342]], dtype=float32)

# %%
dim=embedding.shape[1]
dim
# Out:
# 384

# %%
index = faiss.IndexFlatL2(dim)  #L2-similarity search,fix the dimension
index.add(np.array(embedding))  #all the vector embeddings stored in index like object
print(index)
# Out:
# <faiss.swigfaiss_avx2.IndexFlatL2; proxy of <Swig Object of type 'faiss::IndexFlatL2 *' at 0x7a5564d708d0> >

# %%
generator = pipeline('text-generation',model='gpt2')

# %%
nlp=spacy.load('en_core_web_sm')

# %%
# ----------------------------
# STEP 5: RAG Function
# ----------------------------
def rag_query(query, top_k=2):
    docs=nlp(query)
    print(docs,type(docs))
    filter_words=[]
    for token in docs:
      filter_words.append(token.lemma_)
      updated_query=' '.join(filter_words)
    print(updated_query)

    # Convert query to embedding
    query_embedding = embedding_model.encode([updated_query])

    # Search similar docs
    distances, indices = index.search(np.array(query_embedding), top_k)
    print(distances,indices)
    print(indices[0])
    # Retrieve relevant documents
    retrieved_docs = [chunks[i] for i in indices[0]]

    # # Create augmented prompt
    context = " ".join(retrieved_docs)
    prompt = f"Answer the question based on the context.\n\nContext: {context}\n\nQuestion: {query}\nAnswer:"

    # # Generate answer
    result = generator(prompt, max_length=150, num_return_sequences=1)

    return result[0]["generated_text"]


# ----------------------------
# STEP 6: Test Query
# ----------------------------
query="What is Machine Learning?".lower()
response = rag_query(query)
print(response)
